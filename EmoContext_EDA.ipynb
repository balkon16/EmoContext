# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Wstępna analiza danych EmoContext

# %% [markdown]
# Posiadamy następujące pliki w folderze `data`:

# %%
! ls ./data -1
# Out:
# test_with_labels.txt
# test_without_labels.txt
# training.txt
# validation.txt

# %% [markdown]
# ## Zestaw treningowy

# %%
training_df = pd.read_csv("./data/training.txt", sep='\t')

# %%
training_df.head()
# Out:
#    id                  turn1  \
# 0   0  Don't worry  I'm girl
# 1   1            When did I?
# 2   2                     By
# 3   3         U r ridiculous
# 4   4     Just for time pass
#
#                                                turn2  \
# 0                       hmm how do I know if you are
# 1                         saw many times i think -_-
# 2                                   by Google Chrome
# 3  I might be ridiculous but I am telling the truth.
# 4                         wt do u do 4 a living then
#
#                        turn3   label
# 0            What's ur name?  others
# 1        No. I never saw you   angry
# 2             Where you live  others
# 3  U little disgusting whore   angry
# 4                      Maybe  others

# %%
training_df.tail()
# Out:
#           id                    turn1  \
# 30155  30155             I don't work
# 30156  30156  I'm not getting you 😭😭😭
# 30157  30157                     Haha
# 30158  30158             Do you sing?
# 30159  30159                    Me to
#
#                                          turn2  \
# 30155                  I could take your shift
# 30156                     Why are you crying??
# 30157  no, seriously. What is up with that o-o
# 30158                                yea a lil
# 30159               People be driving me crazy
#
#                                       turn3   label
# 30155                        I am a student  others
# 30156  Because you are not making any sense     sad
# 30157                   Had your breakfast?  others
# 30158                                  Nice  others
# 30159                 Come on sleep with me  others

# %% [markdown]
# ## Zestaw walidacyjny

# %%
validation_df = pd.read_csv("./data/validation.txt", sep = "\t")

# %%
validation_df.head()
# Out:
#    id                    turn1                                       turn2  \
# 0   0         Then dont ask me  YOURE A GUY NOT AS IF YOU WOULD UNDERSTAND
# 1   1  Mixed things  such as??                          the things you do.
# 2   2     Today I'm very happy                     and I'm happy for you ❤
# 3   3       Woah bring me some                          left it there oops
# 4   4            it is thooooo                         I said soon master.
#
#                      turn3   label
# 0    IM NOT A GUY FUCK OFF   angry
# 1  Have you seen minions??  others
# 2          I will be marry   happy
# 3                      Brb  others
# 4      he is pressuring me  others

# %%
validation_df.tail()
# Out:
#         id               turn1                               turn2  \
# 2750  2750       U are my book  book for what? ugliness? THANK YOU
# 2751  2751      I'll be crying     You just want to make ppl cry:P
# 2752  2752  Thanks for sending           hahaha you're welcome! 😤😤
# 2753  2753            Write it                               Mr. F
# 2754  2754                 Yes         okay I'll give you a ticket
#
#                       turn3   label
# 2750         U like ur self  others
# 2751                    ppl  others
# 2752  Why are u not sending  others
# 2753       U understand me?  others
# 2754                    Ohk  others

# %% [markdown]
# ## Zestaw testowy

# %% [markdown]
# Zestaw treningowy, w odróżnieniu od dwóch poprzednich, nie posiada kolumny `label`:

# %%
test_df = pd.read_csv("./data/test_without_labels.txt", sep='\t')

# %%
test_df.head()
# Out:
#    id               turn1                     turn2  \
# 0   0                 Hmm  What does your bio mean?
# 1   1       What you like        very little things
# 2   2                 Yes                   How so?
# 3   3  what did you guess                 what what
# 4   4                We ?        of course we will!
#
#                            turn3
# 0           I don’t have any bio
# 1                            Ok
# 2            I want to fuck babu
# 3                           fuck
# 4  What gender movies you like??

# %%
test_df.tail()
# Out:
#         id                           turn1  \
# 5504  5504                       Not youuu
# 5505  5505                         Welcome
# 5506  5506                             Yes
# 5507  5507              For my information
# 5508  5508  ok........... where you work ?
#
#                                                turn2                   turn3
# 5504                          I also didn't not not.            How to calll
# 5505                                 Why, thank you.  I don't know, you tell
# 5506                     IF ONLY I COULD AFFORD THIS             How are you
# 5507  It's our responsibility to clarify everything.   What is mountain dew?
# 5508                         I'm off this whole week       ok..............

# %% [markdown]
# ## Odpowiedzi do zestawu treningowego (golden standard)

# %%
test_set_answers = pd.read_csv("./data/test_with_labels.txt", sep="\t", usecols=["label"])

# %%
test_set_answers.head()
# Out:
#     label
# 0  others
# 1  others
# 2  others
# 3  others
# 4  others

# %%
test_set_answers.tail()
# Out:
#        label
# 5504  others
# 5505  others
# 5506  others
# 5507  others
# 5508  others

# %% [markdown]
# ## Niepotrzebne kolumny

# %% [markdown]
# Jako, że kolumna `id` duplikuje informację z pandasowego indeksu, usuwam ją:

# %%
training_df.drop('id', axis=1, inplace=True)
test_df.drop('id', axis=1, inplace=True)
validation_df.drop('id', axis=1, inplace=True)

# %% [markdown]
# ## Brakujące dane

# %% [markdown]
# Nie ma żadnych braków danych:

# %%
training_df.isnull().any().any()
# Out:
# False

# %%
test_df.isnull().any().any()
# Out:
# False

# %%
validation_df.isnull().any().any()
# Out:
# False

# %% [markdown]
# ## Kodowanie emotikonek

# %% [markdown]
# W niektórych wiadomościach występują emotikonki. Myślę, że mogą stanowić istotną cechę przy wyborze kategorii. Jak są kodowane?

# %%
emoticon_row = training_df.iloc[21]

# %%
emoticon_row.loc['turn2']
# Out:
# 'Yes I love to dance 😻'

# %%
emoticon_row.loc['turn3']
# Out:
# '😂😂😂 so you have legs too'

# %% [markdown]
# Okazuje się, że emojis są częścią Unicode i są kodowane tak samo jako inne znaki. Do ich poprawnego wyświetlenia potrzebna jest czcionka, która potrafi renderować specjalne (jak na standardy alfabetu łacińskiego znaki), np. chińskie znaki czy emotikony (ang. glyphs). Więcej tutaj: https://stackoverflow.com/questions/19091320/special-characters-emoticons-in-text-file

# %%
emoticon_row.loc['turn3'].encode("utf-8")
# Out:
# b'\xf0\x9f\x98\x82\xf0\x9f\x98\x82\xf0\x9f\x98\x82 so you have legs too'

# %%
emoticon_row.loc['turn2'].encode("utf-8")
# Out:
# b'Yes I love to dance \xf0\x9f\x98\xbb'

# %%
emoticon_row_2 = training_df.iloc[38]
emoticon_row_2
# Out:
# turn1                   That was mean
# turn2    haha the truth usually is. 👍
# turn3            Are you bored of me?
# label                          others
# Name: 38, dtype: object

# %%
emoticon_row_2.loc['turn2'].encode("utf-8")
# Out:
# b'haha the truth usually is. \xf0\x9f\x91\x8d'

# %% [markdown]
# Jak widać poniżej `b''` koduje w postaci ASCII:

# %%
emoticon_row_2.loc['turn2'].encode("utf-8")[0]
# Out:
# 104

# %% [markdown]
# Emotikonka ma długość 1 (w kodowaniu Unicode):

# %%
len(emoticon_row_2.loc['turn2'][-1])
# Out:
# 1

# %% [markdown]
# ## Rozkład zmiennych

# %%
def get_set_statistics(set_df):
    """
    The function returns a dataframe that produces aggregated summary for each of four columns in the input dataframe (`set_df`): `label`, `turn1`, `turn2`, `turn3`.
    Aggregated summary contains information on frequency (`count`) and relative frequency (`freq`) for the `label` column. 
    Each of `turn*` columns is summarised with 
        the average length of the message (`average_len`), 
        standard deviation of the message's length (`std_avg_len`)
        the length of the shortest message in the column (`min_len`),
        the length of the longest message in the the column (`max_len`).
    """
    
    no_rows = set_df.shape[0]
    
    aggregation = {
    'label': {
        'count': 'count',
        'freq': lambda x: x.shape[0]/no_rows
    },
    'turn1': {
        'average_len': lambda x: np.mean(x.str.len()),
        'std_avg_len': lambda x: np.std(x.str.len()),
        'min_len': lambda x: np.min(x.str.len()),
        'max_len': lambda x: np.max(x.str.len())
    },
    'turn2': {
        'average_len': lambda x: np.mean(x.str.len()),
        'std_avg_len': lambda x: np.std(x.str.len()),
        'min_len': lambda x: np.min(x.str.len()),
        'max_len': lambda x: np.max(x.str.len())
    },
    'turn3': {
        'average_len': lambda x: np.mean(x.str.len()),
        'std_avg_len': lambda x: np.std(x.str.len()),
        'min_len': lambda x: np.min(x.str.len()),
        'max_len': lambda x: np.max(x.str.len())
    }
    }
    
    print("The set contains {} observations".format(set_df.shape[0]))
    aggregated_df = set_df.groupby(by='label').agg(aggregation).round(2).sort_values(by=[('label', 'count')], ascending=False)
    return aggregated_df

# %% [markdown]
# ### Treningowe

# %%
get_set_statistics(training_df)
# Out:
# The set contains 30160 observations
# /home/pawel/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py:4656: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#         label             turn1                                   turn2  \
#         count  freq average_len std_avg_len min_len max_len average_len
# label
# others  14948  0.50       17.46       13.61       1     308       25.49
# angry    5506  0.18       20.92       16.44       1     175       26.50
# sad      5463  0.18       18.55       14.54       1     238       24.35
# happy    4243  0.14       19.96       13.43       1     130       27.93
#
#                                          turn3
#        std_avg_len min_len max_len average_len std_avg_len min_len max_len
# label
# others       16.34       1     149       16.93       15.01       1     630
# angry        16.62       1     114       22.19       17.21       1     197
# sad          15.43       1     115       18.86       14.82       1     142
# happy        16.11       1     111       14.09       12.20       1     160

# %% [markdown]
# ### Walidacyjne

# %%
get_set_statistics(validation_df)
# Out:
# /home/pawel/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py:4656: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# The set contains 2755 observations
#        label             turn1                                   turn2  \
#        count  freq average_len std_avg_len min_len max_len average_len
# label
# others  2338  0.85       17.54       13.11       1     122       25.69
# angry    150  0.05       19.01       13.25       1      88       27.91
# happy    142  0.05       18.85       12.76       1      66       28.30
# sad      125  0.05       19.94       27.21       2     286       22.90
#
#                                          turn3
#        std_avg_len min_len max_len average_len std_avg_len min_len max_len
# label
# others       16.72       2     101       16.92       13.54       1     206
# angry        17.09       3      81       19.10       15.60       3     111
# happy        17.19       3      95       13.97       16.55       1     119
# sad          14.42       3      82       19.78       13.51       1      66

# %% [markdown]
# ### Testowe

# %% [markdown]
# Jako, że ramka danych z obserwacjami testowymi nie zawiera kategorii, tworzę tymczasową ramkę danych:

# %%
test_df['label'] = test_set_answers
test_df.head()
# Out:
#                 turn1                     turn2  \
# 0                 Hmm  What does your bio mean?
# 1       What you like        very little things
# 2                 Yes                   How so?
# 3  what did you guess                 what what
# 4                We ?        of course we will!
#
#                            turn3   label
# 0           I don’t have any bio  others
# 1                            Ok   others
# 2            I want to fuck babu  others
# 3                           fuck  others
# 4  What gender movies you like??  others

# %%
get_set_statistics(test_df)
# Out:
# The set contains 5509 observations
# /home/pawel/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py:4656: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#        label             turn1                                   turn2  \
#        count  freq average_len std_avg_len min_len max_len average_len
# label
# others  4677  0.85       17.69       14.33       1     293       25.91
# angry    298  0.05       17.91       12.73       1     116       24.60
# happy    284  0.05       20.54       15.98       1     172       25.91
# sad      250  0.05       19.95       31.03       1     458       25.50
#
#                                          turn3
#        std_avg_len min_len max_len average_len std_avg_len min_len max_len
# label
# others       16.74       1     105       16.85       16.22       1     460
# angry        15.41       4      85       19.77       14.38       1     101
# happy        14.49       4      77       13.37       14.00       1      85
# sad          16.75       3      82       17.90       23.07       1     308

# %%
test_df.drop('label', axis=1, inplace=True)

# %% [markdown]
# ## Najkrótsze wiadomości

# %% [markdown]
# Najkrótsze wiadomości w zestawie mają tylko jeden znak. Czy są to tylko emotikonki? Co z wiadomościami trochę dłuższymi (np. do czterech znaków włącznie)?

# %%
def get_shortest_messages(set_df, one_char = False, limit = 4, head=True):
    """
    TODO function desc
    """
    if one_char:
        # the maximum length of the message is one
        limit = 1
    mask = (set_df['turn1'].str.len() <= limit) | (set_df['turn2'].str.len() <= limit) | (set_df['turn3'].str.len() <= limit)
    if head:
        return set_df.loc[mask].head(15)
    return set_df.loc[mask]

# %% [markdown]
# ### Treningowe

# %%
get_shortest_messages(training_df, one_char=True)
# Out:
#                                            turn1  \
# 19                        Ur creator is very bad
# 24       Bcoz u dont know wat is to miss someone
# 67                                     😂 😂 right
# 152                 I have a good sense of humor
# 153                                 But who paid
# 182  Haha! I act so dumb sometimes and I knew it
# 191                             Tell me about it
# 206                                            ?
# 218                       You cannot see my hair
# 265                        K think me as husband
# 311                              Only 2 are left
# 402                               I'm so excited
# 430                         But u seem so unreal
# 444                                            K
# 498                              I am a good boy
#
#                                                 turn2             turn3  \
# 19            you are only the creator of your brain.                 😑
# 24           but sometimes one can't express the same                 😢
# 67                  Appatasiri. High five then! 🖑😂😂😂😂                 😂
# 152                             I think that's funny.                 😁
# 153                                     still waiting                 😂
# 182                       Haha. How was it though? :3                 😁
# 191                                       your header                 😂
# 206               u asked me if u cn ask me something  I mean pussy cat
# 218                                I'm in your closet                 😂
# 265  Spoken like a person who has never been married.                 S
# 311                                      Count me in!                 😂
# 402           AHHH I'LL HAVE TO LOOK OUT FOR YOU THEN                 👌
# 430                                             i am!                 😞
# 444                                          U are ok       I am not ok
# 498                                    are you cute 😺                 S
#
#       label
# 19      sad
# 24      sad
# 67    happy
# 152   happy
# 153   happy
# 182  others
# 191   happy
# 206  others
# 218   happy
# 265  others
# 311   happy
# 402   happy
# 430     sad
# 444     sad
# 498  others

# %%
get_shortest_messages(training_df)
# Out:
#                                       turn1  \
# 2                                        By
# 7                                        Ok
# 9                                       Bay
# 10                      I hate my boyfriend
# 13                                      Bad
# 14                          Ok get it......
# 15          Money money and lots of money😍😍
# 16                            My gf left ne
# 18            You are lying and i know that
# 19                   Ur creator is very bad
# 24  Bcoz u dont know wat is to miss someone
# 25                                     Yeah
# 29                                      wth
# 30                                  so rude
# 31                                ok i will
#
#                                                 turn2  \
# 2                                    by Google Chrome
# 7                                        ok im back!!
# 9                                          in the bay
# 10                               you got a boyfriend?
# 13               Bad bad! That's the bad kind of bad.
# 14                                I made it an option
# 15  I need to get it tailored but I'm in love with...
# 16             Get over it. Go out with someone else.
# 18                        I KNOW YOU'RE LYING, AB BYS
# 19            you are only the creator of your brain.
# 24           but sometimes one can't express the same
# 25                                    i'll ask around
# 29                               my thoughts exactly!
# 30                                               why?
# 31                                          THANK YOU
#
#                                  turn3   label
# 2                       Where you live  others
# 7                        So, how are u  others
# 9                           😘 love you  others
# 10                                 Yes   angry
# 13                        I have no gf     sad
# 14                                  Ok  others
# 15                                  😁😁   happy
# 16                                 Me*     sad
# 18                                  😭😭     sad
# 19                                   😑     sad
# 24                                   😢     sad
# 25       Which is your favourite movie  others
# 29  you know you are a machine, right?  others
# 30             u didnt ans my question   angry
# 31                                wlcm  others

# %% [markdown]
# ### Walidacyjne

# %%
get_shortest_messages(validation_df, one_char=True)
# Out:
#                           turn1  \
# 8                 Shall we meet
# 22   Send me any video or songs
# 131          I mean, what else?
# 168          Did you married me
# 263                           ?
# 305                           ?
# 348         better do skydiving
# 354                           ?
# 394                    U and me
# 409                  Wr r frm 😜
# 411         I also like to sing
# 438                           3
# 452             Where in gujrat
# 482   How many bf did you have?
# 502                I think so..
#
#                                                  turn2                  turn3  \
# 8    you say- you're leaving soon...anywhere you wa...                      ?
# 22                                       Video or Text                      S
# 131                                   Aiyyo! at all XD                      😂
# 168                                          yes I did                      ?
# 263                               ITS TOO PINK FOR ME.               Too pink
# 305                       you know well what you did !  You you don't like it
# 348  If at first you don't succeed, don't take up s...                      k
# 354                               Go on... This thing?              R u there
# 394                      I don't WANT to handle you...                      😢
# 409                  lol. I saw 1st half last night. 😜                      😅
# 411  You can't! Never!Though you can sing like your...                      😐
# 438                     What? You don't have time only          Time for what
# 452  Trier - a small German city near the Luxembour...                      😮
# 482                  One girlfriend, three boyfriends.                      😂
# 502                                    you think what?                      😂
#
#       label
# 8    others
# 22   others
# 131   happy
# 168  others
# 263  others
# 305  others
# 348  others
# 354  others
# 394     sad
# 409   happy
# 411  others
# 438  others
# 452  others
# 482   happy
# 502  others

# %%
get_shortest_messages(validation_df)
# Out:
#                            turn1  \
# 3             Woah bring me some
# 8                  Shall we meet
# 10                 Your  pic  pz
# 15                            Ok
# 21                        But...
# 22    Send me any video or songs
# 23                           Why
# 33                           You
# 35                          Hell
# 39                            Ok
# 42  So tht u r body can get heat
# 44                          Why!
# 45                          Make
# 52                          Okay
# 53                   No .l human
#
#                                                 turn2  \
# 3                                  left it there oops
# 8   you say- you're leaving soon...anywhere you wa...
# 10                                      thank you X‑D
# 15                                      Thank you. xD
# 21                                               then
# 22                                      Video or Text
# 23                                           why what
# 33                how about ur family.. Still single?
# 35                            im already there xoxo 😂
# 39                       ... tries to ignore pain :'(
# 42                        I heat more than that up ;]
# 44                           Because they are BFF's ?
# 45                                                how
# 52                                Hello! How are you?
# 53                                      Are you sure?
#
#                            turn3   label
# 3                            Brb  others
# 8                              ?  others
# 10                            wc  others
# 15           What about cortanan  others
# 21           I'm feeling nervous     sad
# 22                             S  others
# 23                       How r u  others
# 33               Can you love mi  others
# 35  Good night sweet dreams baby  others
# 39                  Where to go?  others
# 42                            Ok  others
# 44                 Who are BFF's  others
# 45   I don't know I think u know  others
# 52                      Good n u  others
# 53                          Yeah  others

# %% [markdown]
# ### Testowe

# %%
get_shortest_messages(test_df, one_char=True)
# Out:
#                                       turn1  \
# 9                            Nice to meet u
# 63                          Whenever I want
# 76                          Let me love you
# 92   Yes. Yes. Yes. Yes. Yes. Yes. Yes. Yes
# 118                           I'm also good
# 124                          Wat do u mean?
# 195                                       ?
# 382                           Coz I want to
# 428                       Love   😘👭👫❤️❤️you
# 434                                       💩
# 436               Lets play the emojii game
# 439              I want to ask my crush out
# 443                           I like jalebi
# 571                      I was just kidding
# 595                   Tell me magical words
#
#                                                  turn2  \
# 9                         Hi, nice to meet you too! 😸😂
# 63                                    same pinch!!! =/
# 76                          Amazing song though ! :'‑)
# 92                                       no yes no yes
# 118                                     you're welcome
# 124                                  i mean ear :D LOL
# 195  sounds like some young kids tag names frm the ...
# 382                                WHY ARE WE YELLING?
# 428                        looking so beautiful ma ! 😀
# 434                                       Already did.
# 436                                        yup I guess
# 439  Your crush may crush you. So be careful what y...
# 443                                           😒 Weird.
# 571                                           Not you.
# 595    Tell me those 3 magical words. I have cousin.💓💓
#
#                               turn3
# 9                                 😁
# 63                                😁
# 76                                😂
# 92                                😂
# 118                               😀
# 124                               😂
# 195  sounds like you wanna have sex
# 382                               🙄
# 428                               💛
# 434                               😆
# 436                               🏀
# 439                               🎈
# 443                               🙄
# 571                               😆
# 595                               💔

# %%
get_shortest_messages(test_df)
# Out:
#                      turn1                                     turn2  \
# 0                      Hmm                  What does your bio mean?
# 1            What you like                        very little things
# 2                      Yes                                   How so?
# 3       what did you guess                                 what what
# 4                     We ?                        of course we will!
# 9           Nice to meet u              Hi, nice to meet you too! 😸😂
# 10                    Yupp                                      why?
# 13     First  you  hurt me                                      okay
# 17                      by                                 In Suits.
# 24  sure will u cal me ni8                                        Ok
# 29                     Uuu  no i'n not !! what's wrong with you ?!?!
# 31                      Ok                Hey you don't belong here!
# 37                     Buy         Oh, you're buying me a car? Okays
# 44   I already heard of ir                        that proves a lot.
# 46          Love u anyways                         Forever and a day
#
#                             turn3
# 0            I don’t have any bio
# 1                             Ok
# 2             I want to fuck babu
# 3                            fuck
# 4   What gender movies you like??
# 9                               😁
# 10           Don't know I'm tired
# 13              So I talked  rude
# 17                  have good day
# 24                           then
# 29                     I hate uuu
# 31                  I belong here
# 37                     See u soon
# 44                             It
# 46                            Bye

# %% [markdown]
# Powyższe ramki danych pokazują, że wiadomości o długości niekoniecznie są emotikonkami. Mogą to być pojedyncze litery lub znaki interpunkcyjne.

# %% [markdown]
# ## Emotikonki i kategorie

# %% [markdown]
# Czy istnieje zależność pomiędzy ikonką występującą, w którejś wiadomości a kategorią (`label`)?

# %% [markdown]
# Filtruję tylko te konwersacje, gdzie występuje co najmniej jedna emotikonka. Każda emotikonka jest zapisana w następujący sposób: `\x..\x..\x..\x..`, gdzie `.` to cyfra lub litera.

# %%
emoji_pattern = re.compile(u"(["                    
u"\U0001F600-\U0001F64F"  # emoticons
u"\U0001F300-\U0001F5FF"  # symbols & pictographs
u"\U0001F680-\U0001F6FF"  # transport & map symbols
u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                "])", flags= re.UNICODE)

# %%
def is_row_with_emojis(cell):
    """
    TODO function def
    """
    if len(re.findall(emoji_pattern, cell)) > 0:
        return True
    return False

# %%
def purge_non_emojis(cell):
    return ''.join(re.findall(emoji_pattern, cell))

# %%
def get_rows_with_emoticons(set_df):
    """
    """
    mask = (set_df['turn1'].apply(is_row_with_emojis)) | (set_df['turn2'].apply(is_row_with_emojis)) | (set_df['turn3'].apply(is_row_with_emojis))
    
    # filtered out rows don't contain any emojis
    emojis_df = set_df.loc[mask]
    
    # keep the `label` column
    label_col = emojis_df['label']
    
    emojis_df = emojis_df.applymap(purge_non_emojis)
    
    emojis_df['label'] = label_col
    
    return emojis_df

# %% [markdown]
# ### Treningowe

# %%
training_df_emojis_only = get_rows_with_emoticons(training_df)

training_df_emojis_only.head()
# Out:
#    turn1 turn2 turn3   label
# 9                  😘  others
# 15    😍😍     😍    😁😁   happy
# 18                😭😭     sad
# 19                 😑     sad
# 21           😻   😂😂😂   happy

# %% [markdown]
# ### Walidacyjne

# %%
validation_df_emojis_only = get_rows_with_emoticons(validation_df)

validation_df_emojis_only.head()
# Out:
#    turn1 turn2 turn3   label
# 13           😿           sad
# 16           😹        others
# 35           😂        others
# 47     😂              others
# 56                😂😂   happy

# %% [markdown]
# ### Testowe

# %%
# tymczasowo dodaj `label` do `test_df`
test_df['label'] = test_set_answers

# %%
test_df_emojis_only = get_rows_with_emoticons(test_df)

test_df_emojis_only.head()
# Out:
#    turn1 turn2 turn3   label
# 6                  😁   happy
# 9           😸😂     😁   happy
# 14     🙊     😏     🙊  others
# 19           👍        others
# 21        😁😁😁😁        others

# %%
test_df.drop('label', axis=1, inplace=True)

# %% [markdown]
# Sprawdzam ile procent poszczególnych zestawów to obserwacje zawierające co najmniej jedną emotikonkę. Okazuje się, że maksymalnie obserwacji ma co najmniej jedną emotikonkę.

# %%
def get_percentage_emojis_rows(df_full, df_emojis_only):
    """
    TODO: doc
    """
    return df_emojis_only.shape[0]/df_full.shape[0]

# %%
### Treningowe
get_percentage_emojis_rows(training_df, training_df_emojis_only)
# Out:
# 0.16982758620689656

# %%
### Walidacyjne
get_percentage_emojis_rows(validation_df, validation_df_emojis_only)
# Out:
# 0.10417422867513612

# %%
### Testowe
get_percentage_emojis_rows(test_df, test_df_emojis_only)
# Out:
# 0.11944091486658195

# %% [markdown]
# ## Unikalne emotikonki w zbiorze

# %% [markdown]
# Znalezienie unikalnych emotikonek w zbiorze ma za zadanie pomóc w ręcznym sklasyfikowaniu poszczególnych emotikonek w czterech kategoriach. Kategoria `others` ma zostać użyta tylko jeżeli nie jesteśmy pewni do której z trzech pozostałych kategorii wrzucić emotikonkę. Działam jedynie na danych treningowych.

# %%
training_df_emojis_only = get_rows_with_emoticons(training_df)

# %%
testowa_df = get_rows_with_emoticons(training_df).head(5)

# %%
def get_unique_emojis(set_df):
    """
    Given a dataframe get a set of unique emojis
    from the input dataframe.
    """
    
    unique_emojis = set()
    
    for _, *cells in set_df.drop(['label'], axis=1).itertuples():
        for cell in cells:
            emojis = list(cell)
            unique_emojis.update(emojis)
    return unique_emojis

# %%
unique_emojis_training_set = get_unique_emojis(training_df_emojis_only)

# %%
len(unique_emojis_training_set)
# Out:
# 221

# %%
unique_emojis_training_set
# Out:
# {'🌍',
#  '🌞',
#  '🌟',
#  '🌱',
#  '🌷',
#  '🌸',
#  '🌹',
#  '🍌',
#  '🍒',
#  '🍓',
#  '🍗',
#  '🍜',
#  '🍞',
#  '🍭',
#  '🍰',
#  '🍶',
#  '🍷',
#  '🍺',
#  '🍻',
#  '🍼',
#  '🍾',
#  '🎁',
#  '🎂',
#  '🎃',
#  '🎈',
#  '🎉',
#  '🎧',
#  '🎵',
#  '🎶',
#  '🏀',
#  '🏃',
#  '🏋',
#  '🏕',
#  '🏖',
#  '🏡',
#  '🏣',
#  '🏻',
#  '🏼',
#  '🏽',
#  '🏾',
#  '🏿',
#  '🐇',
#  '🐍',
#  '🐒',
#  '🐓',
#  '🐔',
#  '🐘',
#  '🐙',
#  '🐛',
#  '🐝',
#  '🐞',
#  '🐠',
#  '🐨',
#  '🐬',
#  '🐭',
#  '🐰',
#  '🐱',
#  '🐶',
#  '🐷',
#  '🐹',
#  '🐺',
#  '🐻',
#  '🐼',
#  '👀',
#  '👄',
#  '👅',
#  '👆',
#  '👇',
#  '👈',
#  '👉',
#  '👊',
#  '👋',
#  '👌',
#  '👍',
#  '👎',
#  '👏',
#  '👐',
#  '👗',
#  '👙',
#  '👦',
#  '👧',
#  '👨',
#  '👩',
#  '👪',
#  '👫',
#  '👬',
#  '👭',
#  '👮',
#  '👯',
#  '👵',
#  '👶',
#  '👷',
#  '👺',
#  '👻',
#  '👼',
#  '👽',
#  '👿',
#  '💁',
#  '💃',
#  '💋',
#  '💍',
#  '💎',
#  '💐',
#  '💑',
#  '💓',
#  '💔',
#  '💕',
#  '💖',
#  '💗',
#  '💘',
#  '💙',
#  '💚',
#  '💛',
#  '💜',
#  '💝',
#  '💞',
#  '💡',
#  '💤',
#  '💩',
#  '💪',
#  '💭',
#  '💯',
#  '💰',
#  '💵',
#  '📆',
#  '📞',
#  '📲',
#  '🔊',
#  '🔙',
#  '🔜',
#  '🔥',
#  '🔪',
#  '🔱',
#  '🕺',
#  '🖑',
#  '🖕',
#  '😀',
#  '😁',
#  '😂',
#  '😃',
#  '😄',
#  '😅',
#  '😆',
#  '😇',
#  '😈',
#  '😉',
#  '😊',
#  '😋',
#  '😌',
#  '😍',
#  '😎',
#  '😏',
#  '😐',
#  '😑',
#  '😒',
#  '😓',
#  '😔',
#  '😕',
#  '😖',
#  '😗',
#  '😘',
#  '😙',
#  '😚',
#  '😛',
#  '😜',
#  '😝',
#  '😞',
#  '😟',
#  '😠',
#  '😡',
#  '😢',
#  '😣',
#  '😤',
#  '😥',
#  '😦',
#  '😧',
#  '😨',
#  '😩',
#  '😪',
#  '😫',
#  '😬',
#  '😭',
#  '😮',
#  '😯',
#  '😰',
#  '😱',
#  '😲',
#  '😳',
#  '😴',
#  '😵',
#  '😶',
#  '😷',
#  '😸',
#  '😹',
#  '😺',
#  '😻',
#  '😼',
#  '😽',
#  '😾',
#  '😿',
#  '🙀',
#  '🙁',
#  '🙂',
#  '🙃',
#  '🙄',
#  '🙆',
#  '🙇',
#  '🙈',
#  '🙉',
#  '🙊',
#  '🙋',
#  '🙌',
#  '🙍',
#  '🙏',
#  '🚌',
#  '🚗',
#  '🚘',
#  '🚦',
#  '🚩',
#  '🚬',
#  '🛰'}

# %% [markdown]
# ## Błędy pisowni

# %% [markdown]
# # TODO
#
# 5. Czy występują słowa z literówka/błędy itp.?
#
# 6. Czy algorytmy, których będziemy używać potrzebują emotikonek w formie b'' czy mogą zostać zakodowane w formie Unicode?
#
# 7. Napisać funkcję, która grupując po `label` zliczy dla każdej obserwacji unikalne emotikonki dla każdej `turn*`
#
# 8. Użycie embeddingów z Twittera (może są jakieś z domeny naszego problemu?)
#
# 9. Wytrenowanie własnych embeddingów na naszych danych treningowych
#
# 10. Tłumaczenie emotikon na słowa, np. :) -> smiling face
